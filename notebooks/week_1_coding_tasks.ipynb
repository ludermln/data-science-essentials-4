# %%
import pandas as pd

# %% [markdown]
# Read this dataset into a DataFrame named hospitals.

# %%
hospitals = pd.read_csv('../data/Hospitals.csv')

# %% [markdown]
# for data path: .. will move back one folder. use tab to autofill and select folders

# %% [markdown]
# Look at the first few rows and then look at the last few. What do you notice?

# %%
hospitals.head()
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
# 2 -1.315620e+07  4.031978e+06         3  11190023
# 3 -1.317190e+07  4.041752e+06         4  17090028
# 4 -1.313208e+07  4.037270e+06         5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# ...

# %%
hospitals.tail(2)
# Out:
#                  X             Y  OBJECTID         ID  \
# 7594 -8.522423e+06  4.718512e+06      7610  191021401
# 7595 -1.244921e+07  4.976468e+06      7611  196784108
#
#                                     NAME                     ADDRESS  \
# 7594  J KENT MCNEW FAMILY MEDICAL CENTER  175 HARRY S TRUMAN PARKWAY
# 7595       UNIVERSITY ORTHOPAEDIC CENTER              590 WAKARA WAY
#
#                 CITY STATE    ZIP           ZIP4  ...             VAL_DATE  \
# 7594       ANNAPOLIS    MD  21401  NOT AVAILABLE  ...  2020/05/05 00:00:00
# 7595  SALT LAKE CITY    UT  84108  NOT AVAILABLE  ...  2020/05/05 00:00:00
#
#                                                 WEBSITE       STATE_ID  \
# 7594  https://aahs.org/locations/j--kent-mcnew-famil...  NOT AVAILABLE
# 7595          https://healthcare.utah.edu/orthopaedics/  NOT AVAILABLE
#
#            ALT_NAME ST_FIPS               OWNER TTL_STAFF  BEDS  \
# 7594  NOT AVAILABLE      24          NON-PROFIT      -999  -999
# ...

# %% [markdown]
# Observations: lots of data, unsure what all of the columns mean

# %% [markdown]
# How many rows and columns does this DataFrame have?

# %%
hospitals.shape
# Out:
# (7596, 34)

# %%
hospitals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7596 entries, 0 to 7595
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           7596 non-null   float64
#  1   Y           7596 non-null   float64
#  2   OBJECTID    7596 non-null   int64
#  3   ID          7596 non-null   int64
#  4   NAME        7596 non-null   object
#  5   ADDRESS     7596 non-null   object
#  6   CITY        7596 non-null   object
#  7   STATE       7596 non-null   object
#  8   ZIP         7596 non-null   int64
#  9   ZIP4        7596 non-null   object
#  10  TELEPHONE   7596 non-null   object
#  11  TYPE        7596 non-null   object
#  12  STATUS      7596 non-null   object
#  13  POPULATION  7596 non-null   int64
#  14  COUNTY      7596 non-null   object
#  15  COUNTYFIPS  7596 non-null   object
#  16  COUNTRY     7596 non-null   object
#  17  LATITUDE    7596 non-null   float64
#  18  LONGITUDE   7596 non-null   float64
# ...

# %% [markdown]
# We don't need all of the columns. Slice the dataframe down so that it only contains the following columns: 'NAME', 'ADDRESS', 'CITY', 'STATE', 'TYPE', 'POPULATION', 'COUNTY', 'COUNTYFIPS', 'NAICS_DESC', 'BEDS'

# %%
hospitals[['NAME', 'ADDRESS', 'CITY', 'STATE', 'TYPE', 'POPULATION', 'COUNTY', 'COUNTYFIPS', 'NAICS_DESC', 'BEDS']]
# Out:
#                                                    NAME  \
# 0                       CENTRAL VALLEY GENERAL HOSPITAL
# 1     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                     EAST LOS ANGELES DOCTORS HOSPITAL
# 3             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                         KINDRED HOSPITAL BALDWIN PARK
# ...                                                 ...
# 7591      ADVENTIST HEALTHCARE WHITE OAK MEDICAL CENTER
# 7592          COPPER QUEEN DOUGLAS EMERGENCY DEPARTMENT
# 7593                          WHITING FORENSIC HOSPITAL
# 7594                 J KENT MCNEW FAMILY MEDICAL CENTER
# 7595                      UNIVERSITY ORTHOPAEDIC CENTER
#
#                          ADDRESS             CITY STATE                TYPE  \
# 0        1025 NORTH DOUTY STREET          HANFORD    CA  GENERAL ACUTE CARE
# 1                 150 VIA MERIDA  WESTLAKE VILAGE    CA  GENERAL ACUTE CARE
# ...

# %%
hospitals = hospitals[['NAME', 'ADDRESS', 'CITY', 'STATE', 'TYPE', 'POPULATION', 'COUNTY', 'COUNTYFIPS', 'NAICS_DESC', 'BEDS']]

# %% [markdown]
# What are the different hospital types (contained in the TYPE column)? Which is the most common?

# %%
hospitals['TYPE'].unique()
# Out:
# array(['GENERAL ACUTE CARE', 'PSYCHIATRIC', 'CHILDREN', 'LONG TERM CARE',
#        'CRITICAL ACCESS', 'REHABILITATION', 'MILITARY', 'WOMEN',
#        'SPECIAL', 'CHRONIC DISEASE'], dtype=object)

# %%
hospitals['TYPE'].nunique()
# Out:
# 10

# %%
hospitals['TYPE'].value_counts()
# Out:
# GENERAL ACUTE CARE    4481
# CRITICAL ACCESS       1027
# PSYCHIATRIC            759
# LONG TERM CARE         431
# REHABILITATION         378
# MILITARY               216
# SPECIAL                145
# CHILDREN               130
# WOMEN                   20
# CHRONIC DISEASE          9
# Name: TYPE, dtype: int64

# %% [markdown]
# Highest count: general acute care

# %% [markdown]
# Find all hospitals in Nashville, Tennessee. Take a look at the BEDS column. What do you notice? Why do you think this is?

# %%
hospitals.loc[(hospitals['CITY'] == 'NASHVILLE') & (hospitals['STATE'] =='TN')]
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# ...

# %% [markdown]
# How to sort by both city AND state? You can satisfy or '|' and and '&'
# Beds with -999 == NaN value?

# %%
hospitals.loc[hospitals['STATE'] == 'TN'] ['COUNTY'].value_counts()
# Out:
# SHELBY        23
# DAVIDSON      15
# HAMILTON      13
# KNOX          11
# WASHINGTON     6
#               ..
# TROUSDALE      1
# HOUSTON        1
# FAYETTE        1
# HENRY          1
# FENTRESS       1
# Name: COUNTY, Length: 80, dtype: int64

# %%
TN_hospitals = hospitals.loc[hospitals['STATE'] == 'TN']

# %% [markdown]
# Which county in TN has the most hospitals?: Shelby

# %%
TN_hospitals['COUNTY'].value_counts()
# Out:
# SHELBY        23
# DAVIDSON      15
# HAMILTON      13
# KNOX          11
# WASHINGTON     6
#               ..
# TROUSDALE      1
# HOUSTON        1
# FAYETTE        1
# HENRY          1
# FENTRESS       1
# Name: COUNTY, Length: 80, dtype: int64

# %% [markdown]
# There are 95 counties in Tennessee. How many of them have no hospitals at all?
# 15=95-80 from list above

# %%
TN_hospitals.shape
# Out:
# (171, 10)
