# %%
import pandas as pd

# %%
physicians = pd.read_csv('../data/primary_care_physicians.csv')

# %% [markdown]
#  2. Filter `physicians` down to just the counties in Tennessee. Save the filtered dataframe back to `physicians`. Verify that the resulting dataframe has 95 rows.

# %%
physicians = physicians.loc[physicians['state'] == 'Tennessee']

# %%
physicians.head()
# Out:
#        FIPS      state    county  primary_care_physicians
# 2432  47001  Tennessee  Anderson                     39.0
# 2433  47003  Tennessee   Bedford                     15.0
# 2434  47005  Tennessee    Benton                      3.0
# 2435  47007  Tennessee   Bledsoe                      1.0
# 2436  47009  Tennessee    Blount                     90.0

# %%
physicians.shape
# Out:
# (95, 4)

# %% [markdown]
#  3. Look at the distribution of the number of primary care physicians. What do you notice?

# %%
physicians['primary_care_physicians'].value_counts()
# Out:
# 2.0      8
# 5.0      7
# 9.0      5
# 3.0      4
# 1.0      4
# 18.0     4
# 12.0     4
# 4.0      4
# 0.0      4
# 6.0      3
# 15.0     3
# 21.0     3
# 8.0      2
# 26.0     2
# 38.0     2
# 14.0     2
# 39.0     2
# 23.0     2
# 22.0     2
# 19.0     2
# 665.0    1
# 129.0    1
# 338.0    1
# 226.0    1
# 17.0     1
# 91.0     1
# 199.0    1
# 806.0    1
# 137.0    1
# 52.0     1
# 90.0     1
# 82.0     1
# 53.0     1
# 30.0     1
# 55.0     1
# 40.0     1
# 520.0    1
# 7.0      1
# 13.0     1
# 403.0    1
# 16.0     1
# 11.0     1
# 37.0     1
# 27.0     1
# 10.0     1
# 43.0     1
# Name: primary_care_physicians, dtype: int64

# %%
physicians['primary_care_physicians'].describe()
# Out:
# count     95.000000
# mean      51.042105
# std      129.311426
# min        0.000000
# 25%        4.500000
# 50%       12.000000
# 75%       26.500000
# max      806.000000
# Name: primary_care_physicians, dtype: float64

# %%
physicians[physicians['primary_care_physicians'] == 0]
# Out:
#        FIPS      state     county  primary_care_physicians
# 2448  47033  Tennessee   Crockett                      0.0
# 2462  47061  Tennessee     Grundy                      0.0
# 2479  47095  Tennessee       Lake                      0.0
# 2519  47175  Tennessee  Van Buren                      0.0

# %% [markdown]
#  4. Now, import the population by county dataset (`population_by_county.csv`) into a DataFrame named `population`.

# %%
population = pd.read_csv('../data/population_by_county.csv')

# %%
population.head()
# Out:
#     FIPS  population          county     state  urban
# 0  17051       21565  Fayette County  ILLINOIS  Rural
# 1  17107       29003    Logan County  ILLINOIS  Rural
# 2  17165       23994   Saline County  ILLINOIS  Rural
# 3  17097      701473     Lake County  ILLINOIS  Urban
# 4  17127       14219   Massac County  ILLINOIS  Rural

# %% [markdown]
#  5. Merge the `physicians` DataFrame with the `population` DataFrame. Keep only the values for Tennessee. When you merge, be sure the include both the `population` and `urban` columns in the merged results. Save the result of the merge back to `physicians`.

# %%
population = population.loc[population['state'] == 'TENNESSEE']

# %%
population.head()
# Out:
#       FIPS  population            county      state  urban
# 283  47165      183437     Sumner County  TENNESSEE  Urban
# 284  47169       10231  Trousdale County  TENNESSEE  Urban
# 285  47027        7654       Clay County  TENNESSEE  Rural
# 405  47157      936374     Shelby County  TENNESSEE  Urban
# 406  47077       27977  Henderson County  TENNESSEE  Rural

# %% [markdown]
# first filter state and save as new df, need to change state case? county also needs to drop county from name.

# %%
physicians['state'] = physicians['state'].str.upper()

# %%
physicians.head()
# Out:
#        FIPS      state    county  primary_care_physicians
# 2432  47001  TENNESSEE  Anderson                     39.0
# 2433  47003  TENNESSEE   Bedford                     15.0
# 2434  47005  TENNESSEE    Benton                      3.0
# 2435  47007  TENNESSEE   Bledsoe                      1.0
# 2436  47009  TENNESSEE    Blount                     90.0

# %%
population['county'].str.rsplit(' ', n = 1, expand = True)
# Out:
#               0       1
# 283      Sumner  County
# 284   Trousdale  County
# 285        Clay  County
# 405      Shelby  County
# 406   Henderson  County
# ...         ...     ...
# 3195     Monroe  County
# 3196      Henry  County
# 3197   Crockett  County
# 3198       Lake  County
# 3199       Knox  County
#
# [95 rows x 2 columns]

# %% [markdown]
# Above code removed 'County' from column in population

# %%
population['county'].str.split(' County', expand = True)
population['county']=population['county'].str.split(' County', expand = True)[0]

# %%
population.head()
# Out:
#       FIPS  population     county      state  urban
# 283  47165      183437     Sumner  TENNESSEE  Urban
# 284  47169       10231  Trousdale  TENNESSEE  Urban
# 285  47027        7654       Clay  TENNESSEE  Rural
# 405  47157      936374     Shelby  TENNESSEE  Urban
# 406  47077       27977  Henderson  TENNESSEE  Rural

# %%
physicians.head()
# Out:
#        FIPS      state    county  primary_care_physicians
# 2432  47001  TENNESSEE  Anderson                     39.0
# 2433  47003  TENNESSEE   Bedford                     15.0
# 2434  47005  TENNESSEE    Benton                      3.0
# 2435  47007  TENNESSEE   Bledsoe                      1.0
# 2436  47009  TENNESSEE    Blount                     90.0

# %%
physicians['county'].value_counts()
# Out:
# Anderson    1
# Meigs       1
# Polk        1
# Pickett     1
# Perry       1
#            ..
# Greene      1
# Grainger    1
# Giles       1
# Gibson      1
# Wilson      1
# Name: county, Length: 95, dtype: int64

# %%
population['county'].value_counts()
# Out:
# Sumner        1
# Giles         1
# Bedford       1
# Williamson    1
# Wayne         1
#              ..
# Fentress      1
# Anderson      1
# Scott         1
# Rhea          1
# Knox          1
# Name: county, Length: 95, dtype: int64

# %% [markdown]
# When you merge, be sure the include both the population and urban columns in the merged results. Save the result of the merge back to physicians.

# %% [markdown]
# couldn't merge on 'county' even though i tried to remove 'County' from column in population, the table woudn't print out. I tried to merge on 'state' but would get multiple entries for each row.
#     merging on 'FIPS' kept the correct number of rows? Unsure why this problem occurs

# %% [markdown]
# see above code: could split on " County". also try str.rsplit?

# %%
pd.merge(left = population, right = physicians, left_on = 'FIPS', right_on = 'FIPS')
# Out:
#      FIPS  population   county_x    state_x  urban    state_y   county_y  \
# 0   47165      183437     Sumner  TENNESSEE  Urban  TENNESSEE     Sumner
# 1   47169       10231  Trousdale  TENNESSEE  Urban  TENNESSEE  Trousdale
# 2   47027        7654       Clay  TENNESSEE  Rural  TENNESSEE       Clay
# 3   47157      936374     Shelby  TENNESSEE  Urban  TENNESSEE     Shelby
# 4   47077       27977  Henderson  TENNESSEE  Rural  TENNESSEE  Henderson
# ..    ...         ...        ...        ...    ...        ...        ...
# 90  47123       46064     Monroe  TENNESSEE  Rural  TENNESSEE     Monroe
# 91  47079       32284      Henry  TENNESSEE  Rural  TENNESSEE      Henry
# 92  47033       14399   Crockett  TENNESSEE  Rural  TENNESSEE   Crockett
# 93  47095        7401       Lake  TENNESSEE  Rural  TENNESSEE       Lake
# 94  47093      461104       Knox  TENNESSEE  Urban  TENNESSEE       Knox
#
#     primary_care_physicians
# 0                      91.0
# 1                       2.0
# 2                       2.0
# 3                     806.0
# 4                       7.0
# ..                      ...
# 90                      9.0
# 91                     22.0
# 92                      0.0
# 93                      0.0
# 94                    520.0
#
# [95 rows x 8 columns]

# %%
physicians = pd.merge(left = population[['FIPS', 'population', 'urban']],
         right = physicians[['FIPS', 'county', 'state', 'primary_care_physicians']])

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0

# %%
physicians.shape
# Out:
# (95, 6)

# %% [markdown]
# 6. How many Tennessee counties are considered urban? (38)

# %%
physicians.loc[(physicians['urban'] == 'Urban')].describe()
# Out:
#                FIPS     population  primary_care_physicians
# count     38.000000      38.000000                38.000000
# mean   47103.789474  131408.552632               108.315789
# std       60.904071  194462.806866               191.346736
# min    47001.000000   10231.000000                 1.000000
# 25%    47049.500000   23286.250000                 6.500000
# 50%    47112.000000   56522.000000                22.500000
# 75%    47160.500000  134981.250000                90.750000
# max    47189.000000  936374.000000               806.000000

# %%
physicians.loc[(physicians['urban'] == 'Urban')].shape
# Out:
# (38, 6)

# %%
physicians['urban'].value_counts()
# Out:
# Rural    57
# Urban    38
# Name: urban, dtype: int64

# %%
population.loc[(population['urban'] == 'Urban')].describe()
# Out:
#                FIPS     population
# count     38.000000      38.000000
# mean   47103.789474  131408.552632
# std       60.904071  194462.806866
# min    47001.000000   10231.000000
# 25%    47049.500000   23286.250000
# 50%    47112.000000   56522.000000
# 75%    47160.500000  134981.250000
# max    47189.000000  936374.000000

# %% [markdown]
#  7. The State Health Access Data Assistance Center (SHADAC) (https://www.shadac.org/) classifies counties into three groups based on the number of residents per primary care physician. First, counties with fewer than 1500 residents per primary care physician are considered to have an "adequate" supply. Counties with at least 1500 residents but fewer than 3500 residents per primary care physician are considered to have a "moderately inadequate" supply, and counties with at least 3500 residents per primary care physician are considered to have a "low inadequate" supply. How many counties in Tennessee are in each group?

# %% [markdown]
# to add a column to table:

# %%
physicians['residents_per_pcp'] = physicians['population'] / physicians['primary_care_physicians']

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
#
#    residents_per_pcp
# 0        2015.791209
# 1        5115.500000

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] < 1500)].nunique()
# Out:
# FIPS                       14
# population                 14
# urban                       2
# county                     14
# state                       1
# primary_care_physicians    14
# residents_per_pcp          14
# dtype: int64

# %%
physicians.loc[(physicians['residents_per_pcp'] < 1500)].shape
# Out:
# (14, 7)

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 1500) & 
               (physicians['population'] / physicians['primary_care_physicians'] < 3500)].nunique()
# Out:
# FIPS                       50
# population                 50
# urban                       2
# county                     50
# state                       1
# primary_care_physicians    29
# residents_per_pcp          50
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 3500)].nunique()
# Out:
# FIPS                       31
# population                 31
# urban                       2
# county                     31
# state                       1
# primary_care_physicians    10
# residents_per_pcp          28
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 3500)]
# Out:
#      FIPS  population  urban      county      state  primary_care_physicians  \
# 1   47169       10231  Urban   Trousdale  TENNESSEE                      2.0
# 2   47027        7654  Rural        Clay  TENNESSEE                      2.0
# 4   47077       27977  Rural   Henderson  TENNESSEE                      7.0
# 9   47135        7962  Rural       Perry  TENNESSEE                      2.0
# 11  47075       17623  Rural     Haywood  TENNESSEE                      5.0
# 13  47061       13344  Rural      Grundy  TENNESSEE                      0.0
# 16  47101       12027  Rural       Lewis  TENNESSEE                      2.0
# 18  47167       61447  Urban      Tipton  TENNESSEE                     17.0
# 25  47117       32965  Rural    Marshall  TENNESSEE                      5.0
# 31  47069       25443  Rural    Hardeman  TENNESSEE                      4.0
# 40  47005       16140  Rural      Benton  TENNESSEE                      3.0
# 41  47007       14836  Rural     Bledsoe  TENNESSEE                      1.0
# 43  47015       14178  Urban      Cannon  TENNESSEE                      3.0
# 44  47083        8164  Rural     Houston  TENNESSEE                      2.0
# 48  47067        6587  Rural     Hancock  TENNESSEE                      1.0
# 49  47073       56611  Urban     Hawkins  TENNESSEE                     15.0
# 52  47111       23842  Urban       Macon  TENNESSEE                      4.0
# 53  47127        6378  Rural       Moore  TENNESSEE                      1.0
# 59  47057       23101  Urban    Grainger  TENNESSEE                      5.0
# 61  47097       25989  Rural  Lauderdale  TENNESSEE                      2.0
# 72  47175        5760  Rural   Van Buren  TENNESSEE                      0.0
# 74  47081       24813  Urban     Hickman  TENNESSEE                      5.0
# 75  47085       18435  Rural   Humphreys  TENNESSEE                      5.0
# 78  47161       13427  Urban     Stewart  TENNESSEE                      1.0
# 79  47023       17190  Urban     Chester  TENNESSEE                      4.0
# 81  47087       11682  Rural     Jackson  TENNESSEE                      2.0
# 86  47173       19488  Urban       Union  TENNESSEE                      3.0
# 89  47129       21545  Rural      Morgan  TENNESSEE                      3.0
# 90  47123       46064  Rural      Monroe  TENNESSEE                      9.0
# 92  47033       14399  Rural    Crockett  TENNESSEE                      0.0
# 93  47095        7401  Rural        Lake  TENNESSEE                      0.0
#
#     residents_per_pcp
# 1        5.115500e+03
# 2        3.827000e+03
# 4        3.996714e+03
# 9        3.981000e+03
# 11       3.524600e+03
# 13                inf
# 16       6.013500e+03
# 18       3.614529e+03
# 25       6.593000e+03
# 31       6.360750e+03
# 40       5.380000e+03
# 41       1.483600e+04
# 43       4.726000e+03
# 44       4.082000e+03
# 48       6.587000e+03
# 49       3.774067e+03
# 52       5.960500e+03
# 53       6.378000e+03
# 59       4.620200e+03
# 61       1.299450e+04
# 72                inf
# 74       4.962600e+03
# 75       3.687000e+03
# 78       1.342700e+04
# 79       4.297500e+03
# 81       5.841000e+03
# 86       6.496000e+03
# 89       7.181667e+03
# 90       5.118222e+03
# 92                inf
# 93                inf

# %% [markdown]
#  8. Does there appear to be any detectable relationship between whether a county is urban or rural and its supply of primary care physicians?
#  More rural counties have moderately inadequate/low inadequate groups

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] < 1500)
              & (physicians['urban'] == 'Urban')].nunique()
# Out:
# FIPS                       9
# population                 9
# urban                      1
# county                     9
# state                      1
# primary_care_physicians    9
# residents_per_pcp          9
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] < 1500)
              & (physicians['urban'] == 'Urban')].describe()
# Out:
#                FIPS     population  primary_care_physicians  residents_per_pcp
# count      9.000000       9.000000                 9.000000           9.000000
# mean   47111.444444  353742.333333               375.111111         911.093607
# std       64.751662  292472.943977               246.970871         269.278617
# min    47009.000000   97625.000000                90.000000         565.508850
# 25%    47065.000000  129927.000000               199.000000         756.782946
# 50%    47113.000000  225389.000000               338.000000         886.738462
# 75%    47163.000000  461104.000000               520.000000        1033.816541
# max    47187.000000  936374.000000               806.000000        1443.633333

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] < 1500)]['urban'].value_counts()
# Out:
# Urban    9
# Rural    5
# Name: urban, dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] < 1500)
              & (physicians['urban'] == 'Rural')].nunique()
# Out:
# FIPS                       5
# population                 5
# urban                      1
# county                     5
# state                      1
# primary_care_physicians    5
# residents_per_pcp          5
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 1500) & 
               (physicians['population'] / physicians['primary_care_physicians'] < 3500)
              & (physicians['urban'] == 'Rural')].nunique()
# Out:
# FIPS                       31
# population                 31
# urban                       1
# county                     31
# state                       1
# primary_care_physicians    21
# residents_per_pcp          31
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 1500) & 
               (physicians['population'] / physicians['primary_care_physicians'] < 3500)
              & (physicians['urban'] == 'Urban')].nunique()
# Out:
# FIPS                       19
# population                 19
# urban                       1
# county                     19
# state                       1
# primary_care_physicians    19
# residents_per_pcp          19
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 3500) &
              (physicians['urban'] == 'Urban')].nunique()
# Out:
# FIPS                       10
# population                 10
# urban                       1
# county                     10
# state                       1
# primary_care_physicians     7
# residents_per_pcp          10
# dtype: int64

# %%
physicians.loc[(physicians['population'] / physicians['primary_care_physicians'] >= 3500) &
              (physicians['urban'] == 'Rural')].nunique()
# Out:
# FIPS                       21
# population                 21
# urban                       1
# county                     21
# state                       1
# primary_care_physicians     8
# residents_per_pcp          18
# dtype: int64

# %% [markdown]
# ##WEEK 3 coding tasks begin

# %%
physicians.loc[physicians['residents_per_pcp'] < 1500, 'shadac_category'] = 'adequate'
physicians.loc[(physicians['residents_per_pcp'] >= 1500) & 
          (physicians['residents_per_pcp'] < 3500), 'shadac_category'] = 'moderately inadequate'
physicians.loc[(physicians['residents_per_pcp'] >= 3500), 'shadac_category'] = 'low inadequate'

# %%
physicians.head()
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
# 2  47027        7654  Rural       Clay  TENNESSEE                      2.0
# 3  47157      936374  Urban     Shelby  TENNESSEE                    806.0
# 4  47077       27977  Rural  Henderson  TENNESSEE                      7.0
#
#    residents_per_pcp        shadac_category
# 0        2015.791209  moderately inadequate
# 1        5115.500000         low inadequate
# 2        3827.000000         low inadequate
# 3        1161.754342               adequate
# 4        3996.714286         low inadequate

# %%
physicians['shadac_category'].value_counts()
# Out:
# moderately inadequate    50
# low inadequate           31
# adequate                 14
# Name: shadac_category, dtype: int64

# %% [markdown]
# 2. Use this new column to investigate if there is any relationship between a county's status as urban or rural and its SHADAC classification. Create a plot showing what you find.

# %%
physicians.groupby(["urban", "shadac_category"]).size()
# Out:
# urban  shadac_category
# Rural  adequate                  5
#        low inadequate           21
#        moderately inadequate    31
# Urban  adequate                  9
#        low inadequate           10
#        moderately inadequate    19
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
pd.crosstab(physicians['urban'], physicians['shadac_category'])
# Out:
# shadac_category  adequate  low inadequate  moderately inadequate
# urban
# Rural                   5              21                     31
# Urban                   9              10                     19

# %%
pd.crosstab(physicians['urban'], physicians['shadac_category']).plot(kind = 'bar', 
                                                          stacked = True,       # stacked as opposed to side-by-side
                                                          color = ['blue', 'red', 'gold'],     # change the default colors
                                                          edgecolor = 'black')              # add a border to the bars
plt.title('SHADAC Category by Urban Distinction')                   # add a title
plt.xticks(rotation = 0);                                             # change the appearance of the x tick labels

# %%
pd.crosstab(physicians['urban'], physicians['shadac_category'], normalize = 'all')
# Out:
# shadac_category  adequate  low inadequate  moderately inadequate
# urban
# Rural            0.052632        0.221053               0.326316
# Urban            0.094737        0.105263               0.200000

# %%
pd.crosstab(physicians['urban'], physicians['shadac_category'], normalize = 'index')
# Out:
# shadac_category  adequate  low inadequate  moderately inadequate
# urban
# Rural            0.087719        0.368421                0.54386
# Urban            0.236842        0.263158                0.50000

# %%
(pd.crosstab(physicians['urban'], physicians['shadac_category'], normalize = 'index')*100).plot(kind = 'bar', 
                                                          stacked = True,       # stacked as opposed to side-by-side
                                                          color = ['blue', 'red', 'gold'],     # change the default colors
                                                          edgecolor = 'black')              # add a border to the bars
plt.title('SHADAC Category by Urban Distinction')                   # add a title
plt.xticks(rotation = 0);                                             # change the appearance of the x tick labels
plt.legend(bbox_to_anchor = (1, 0.8), loc = 'upper left');

# %% [markdown]
# 3. Merge the unemployment data (contained in tn_unemployment.csv) into the physicians DataFrame.

# %%
unemployment = pd.read_csv('../data/tn_unemployment.csv')

# %%
unemployment.head(2)
# Out:
#          laus_code  State  County                 Name  Period     LF  \
# 0  CN4700100000000     47       1  Anderson County, TN  Mar-21  34704
# 1  CN4700300000000     47       3   Bedford County, TN  Mar-21  20623
#
#    Employed  Unemployed  unemployment_rate
# 0     33010        1694                4.9
# 1     19550        1073                5.2

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
#
#    residents_per_pcp        shadac_category
# 0        2015.791209  moderately inadequate
# 1        5115.500000         low inadequate

# %%
unemployment['Name'].str.split(' County', expand = True)
unemployment['Name']=unemployment['Name'].str.split(' County', expand = True)[0]
unemployment.head(2)
# Out:
#          laus_code  State  County      Name  Period     LF  Employed  \
# 0  CN4700100000000     47       1  Anderson  Mar-21  34704     33010
# 1  CN4700300000000     47       3   Bedford  Mar-21  20623     19550
#
#    Unemployed  unemployment_rate
# 0        1694                4.9
# 1        1073                5.2

# %%
unemployment[['Name', 'LF', 'Employed', 'Unemployed', 'unemployment_rate']]
# Out:
#           Name      LF  Employed  Unemployed  unemployment_rate
# 0     Anderson   34704     33010        1694                4.9
# 1      Bedford   20623     19550        1073                5.2
# 2       Benton    6723      6305         418                6.2
# 3      Bledsoe    4252      3947         305                7.2
# 4       Blount   64098     61119        2979                4.6
# ..         ...     ...       ...         ...                ...
# 90       Wayne    6416      6074         342                5.3
# 91     Weakley   15494     14783         711                4.6
# 92       White   12085     11484         601                5.0
# 93  Williamson  129484    125213        4271                3.3
# 94      Wilson   77426     74347        3079                4.0
#
# [95 rows x 5 columns]

# %%
physicians = pd.merge(left = physicians,
         right = unemployment[['Name', 'LF', 'Employed', 'Unemployed', 'unemployment_rate']].rename(columns = {'Name': 'county'}))

# %%
physicians.head()
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
# 2  47027        7654  Rural       Clay  TENNESSEE                      2.0
# 3  47157      936374  Urban     Shelby  TENNESSEE                    806.0
# 4  47077       27977  Rural  Henderson  TENNESSEE                      7.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
# 2        3827.000000         low inadequate    2743      2557         186
# 3        1161.754342               adequate  448170    416726       31444
# 4        3996.714286         low inadequate   11961     11323         638
#
#    unemployment_rate
# 0                4.3
# 1                4.7
# 2                6.8
# 3                7.0
# 4                5.3

# %% [markdown]
#  How do unemployment rates compare for urban counties versus rural counties?

# %%
physicians.groupby('urban')['unemployment_rate'].describe()
# Out:
#        count      mean       std  min    25%   50%    75%  max
# urban
# Rural   57.0  5.850877  0.976349  3.7  5.200  5.60  6.500  9.3
# Urban   38.0  4.918421  0.759749  3.3  4.325  4.85  5.375  7.1

# %%
import seaborn as sns

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data = physicians,
           x = 'unemployment_rate',
           y = 'urban')
# Out:
# <AxesSubplot:xlabel='unemployment_rate', ylabel='urban'>

# %% [markdown]
# Create a new column, `pcp_per_100k` which contains the number of primary care physicians per 100,000 residents. Investigate the relationship between this new measure and the unemployment rate per county. What do you find?

# %%
physicians['pcp_per_100k'] = physicians['primary_care_physicians'] / physicians['population'] * 100000
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
#
#    unemployment_rate  pcp_per_100k
# 0                4.3     49.608312
# 1                4.7     19.548431

# %%
physicians.plot(kind = 'scatter',
             x = 'unemployment_rate',
             y = 'pcp_per_100k',
             figsize = (10,6));

# %%
physicians[['unemployment_rate', 'pcp_per_100k']].corr()
# Out:
#                    unemployment_rate  pcp_per_100k
# unemployment_rate           1.000000     -0.335333
# pcp_per_100k               -0.335333      1.000000

# %% [markdown]
# Start week 4 coding tasks below

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
counties = gpd.read_file('../data/county/tncounty.shp')

# %%
counties = pd.merge(left = counties, 
         right = unemployment.rename(columns = {'Name': 'NAME'})[['NAME', 'unemployment_rate']])
counties.head(2)
# Out:
#    OBJECTID     NAME    KEY    SHAPE_AREA      SHAPE_LEN  \
# 0        76  Chester  47023  8.049024e+09  520461.080124
# 1        77    Wayne  47181  2.050741e+10  666520.678598
#
#                                             geometry  unemployment_rate
# 0  POLYGON ((1137985.762 344601.643, 1137965.070 ...                4.3
# 1  POLYGON ((1365052.057 391716.806, 1365746.554 ...                5.3

# %% [markdown]
# Don't need to keep only 'unemployment_rate' column since you can select column for plotting below in code

# %%
fig, ax = plt.subplots(figsize=(16,4))

counties.plot(column = 'unemployment_rate', 
              edgecolor = 'black', 
              legend = True,
              cmap = 'Blues',
              scheme="NaturalBreaks",
              ax = ax)

# Position the legend
leg = ax.get_legend()
leg.set_bbox_to_anchor((1, 0.5))

# Add a title
plt.title('Unemployment by County, March 2021', fontsize = 18)

ax.axis('off');

# %%
counties.head(2)
# Out:
#    OBJECTID     NAME    KEY    SHAPE_AREA      SHAPE_LEN  \
# 0        76  Chester  47023  8.049024e+09  520461.080124
# 1        77    Wayne  47181  2.050741e+10  666520.678598
#
#                                             geometry  unemployment_rate
# 0  POLYGON ((1137985.762 344601.643, 1137965.070 ...                4.3
# 1  POLYGON ((1365052.057 391716.806, 1365746.554 ...                5.3

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
#
#    unemployment_rate  pcp_per_100k
# 0                4.3     49.608312
# 1                4.7     19.548431

# %%
counties = pd.merge(left = counties, 
         right = physicians.rename(columns = {'county': 'NAME'}))
counties.head(2)
# Out:
#    OBJECTID     NAME    KEY    SHAPE_AREA      SHAPE_LEN  \
# 0        76  Chester  47023  8.049024e+09  520461.080124
# 1        77    Wayne  47181  2.050741e+10  666520.678598
#
#                                             geometry  unemployment_rate  \
# 0  POLYGON ((1137985.762 344601.643, 1137965.070 ...                4.3
# 1  POLYGON ((1365052.057 391716.806, 1365746.554 ...                5.3
#
#     FIPS  population  urban      state  primary_care_physicians  \
# 0  47023       17190  Urban  TENNESSEE                      4.0
# 1  47181       16693  Rural  TENNESSEE                      5.0
#
#    residents_per_pcp        shadac_category    LF  Employed  Unemployed  \
# 0             4297.5         low inadequate  8424      8062         362
# 1             3338.6  moderately inadequate  6416      6074         342
#
#    pcp_per_100k
# 0     23.269343
# 1     29.952675

# %%
fig, ax = plt.subplots(figsize=(16,4))
counties.plot(column = 'shadac_category', 
              edgecolor = 'black', 
              legend = True,
              ax = ax)
ax.axis('off');

# %%
fig, ax = plt.subplots(figsize=(16,4))

counties.plot(column = 'shadac_category', 
              edgecolor = 'black', 
              legend = True,
              cmap = 'Blues',
              ax = ax)

# Position the legend
leg = ax.get_legend()
leg.set_bbox_to_anchor((1, 0.5))

# Add a title
plt.title('SHADAC Category, March 2021', fontsize = 18)

ax.axis('off');

# %%
physicians.head(5)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
# 2  47027        7654  Rural       Clay  TENNESSEE                      2.0
# 3  47157      936374  Urban     Shelby  TENNESSEE                    806.0
# 4  47077       27977  Rural  Henderson  TENNESSEE                      7.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
# 2        3827.000000         low inadequate    2743      2557         186
# 3        1161.754342               adequate  448170    416726       31444
# 4        3996.714286         low inadequate   11961     11323         638
#
#    unemployment_rate  pcp_per_100k
# 0                4.3     49.608312
# 1                4.7     19.548431
# 2                6.8     26.130128
# 3                7.0     86.076717
# 4                5.3     25.020553

# %% [markdown]
# First, TN Med Helper is concerned about communities either lacking access to healthcare or losing access to healthcare. They are looking to expand telehealth technologies into the vulnerable communities, and need your help to priortize areas most needing attention. your first objective is to identify which counties in Tennessee have the most severe lack of access to healthcare (either due to lack of hospitals, physicians, or both). Once you have identified these counties, see if you can find any common demographic or economic characteristics for these areas.

# %%
fig, ax = plt.subplots(figsize=(16,4))

counties.plot(column = 'pcp_per_100k', 
              edgecolor = 'black', 
              legend = True,
                            scheme="NaturalBreaks",
              cmap = 'Blues',
              ax = ax)

# Position the legend
leg = ax.get_legend()
leg.set_bbox_to_anchor((1, 0.5))

# Add a title
plt.title('Primary care physicians per 100k', fontsize = 18)

ax.axis('off');

# %%
help_counties = physicians.loc[(physicians['shadac_category'] == 'low inadequate') & (physicians['pcp_per_100k'] < 26.13)]
help_counties.head()
# Out:
#      FIPS  population  urban     county      state  primary_care_physicians  \
# 1   47169       10231  Urban  Trousdale  TENNESSEE                      2.0
# 4   47077       27977  Rural  Henderson  TENNESSEE                      7.0
# 9   47135        7962  Rural      Perry  TENNESSEE                      2.0
# 13  47061       13344  Rural     Grundy  TENNESSEE                      0.0
# 16  47101       12027  Rural      Lewis  TENNESSEE                      2.0
#
#     residents_per_pcp shadac_category     LF  Employed  Unemployed  \
# 1         5115.500000  low inadequate   5473      5217         256
# 4         3996.714286  low inadequate  11961     11323         638
# 9         3981.000000  low inadequate   3038      2801         237
# 13                inf  low inadequate   4977      4655         322
# 16        6013.500000  low inadequate   5300      5017         283
#
#     unemployment_rate  pcp_per_100k
# 1                 4.7     19.548431
# 4                 5.3     25.020553
# 9                 7.8     25.119317
# 13                6.5      0.000000
# 16                5.3     16.629251

# %% [markdown]
# are the 0 values for some counties (ex. Grundy, Lake, Van Buren) accurate?
#
# help_counties are TN counties that are low inadequate and lowest number of pcp per 100k residents.

# %%
help_counties.loc[(help_counties['primary_care_physicians'] == 0)]
# Out:
#      FIPS  population  urban     county      state  primary_care_physicians  \
# 13  47061       13344  Rural     Grundy  TENNESSEE                      0.0
# 72  47175        5760  Rural  Van Buren  TENNESSEE                      0.0
# 92  47033       14399  Rural   Crockett  TENNESSEE                      0.0
# 93  47095        7401  Rural       Lake  TENNESSEE                      0.0
#
#     residents_per_pcp shadac_category    LF  Employed  Unemployed  \
# 13                inf  low inadequate  4977      4655         322
# 72                inf  low inadequate  2021      1884         137
# 92                inf  low inadequate  6838      6494         344
# 93                inf  low inadequate  1694      1537         157
#
#     unemployment_rate  pcp_per_100k
# 13                6.5           0.0
# 72                6.8           0.0
# 92                5.0           0.0
# 93                9.3           0.0

# %%
hospitals = pd.read_csv('../data/Hospitals.csv')

# %%
hospitals.head(2)
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
#
#                                                 NAME                  ADDRESS  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL  1025 NORTH DOUTY STREET
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...           150 VIA MERIDA
#
#               CITY STATE    ZIP           ZIP4  ...             VAL_DATE  \
# 0          HANFORD    CA  93230  NOT AVAILABLE  ...  2014/02/10 00:00:00
# 1  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE  ...  2014/02/10 00:00:00
#
#                             WEBSITE       STATE_ID       ALT_NAME ST_FIPS  \
# 0      http://www.hanfordhealth.com  NOT AVAILABLE  NOT AVAILABLE       6
# 1  http://www.losrobleshospital.com  NOT AVAILABLE  NOT AVAILABLE       6
#
#          OWNER TTL_STAFF  BEDS         TRAUMA  HELIPAD
# 0  PROPRIETARY      -999    49  NOT AVAILABLE        N
# 1  PROPRIETARY      -999    62  NOT AVAILABLE        N
#
# [2 rows x 34 columns]

# %%
hospitals = hospitals.loc[(hospitals['STATE'] == 'TN')]

# %%
hospitals.head(2)
# Out:
#                 X             Y  OBJECTID        ID  \
# 515 -9.409026e+06  4.210878e+06       517  14737331
# 535 -9.535209e+06  4.348723e+06       537   3438562
#
#                                      NAME                ADDRESS        CITY  \
# 515  STARR REGIONAL MEDICAL CENTER ETOWAH  886 HIGHWAY 411 NORTH      ETOWAH
# 535               JACKSON COUNTY HOSPITAL     620 HOSPITAL DRIVE  GAINESBORO
#
#     STATE    ZIP           ZIP4  ...             VAL_DATE  \
# 515    TN  37331  NOT AVAILABLE  ...  2014/02/10 00:00:00
# 535    TN  38562  NOT AVAILABLE  ...  2014/02/12 00:00:00
#
#                            WEBSITE       STATE_ID                 ALT_NAME  \
# 515  http://www.starrregional.com/  NOT AVAILABLE  WOODS MEMORIAL HOSPITAL
# 535                  NOT AVAILABLE         477446            NOT AVAILABLE
#
#     ST_FIPS       OWNER TTL_STAFF  BEDS         TRAUMA  HELIPAD
# 515      47  NON-PROFIT      -999    72      LEVEL III        Y
# 535      47  NON-PROFIT      -999  -999  NOT AVAILABLE        N
#
# [2 rows x 34 columns]

# %%
hospitals.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %%
hospitals = hospitals['COUNTY'].value_counts().to_frame('Hospital_Count').reset_index().rename(columns = {'index':'COUNTY'})

# %%
hospitals.head()
# Out:
#        COUNTY  Hospital_Count
# 0      SHELBY              23
# 1    DAVIDSON              15
# 2    HAMILTON              13
# 3        KNOX              11
# 4  WASHINGTON               6

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     Sumner  TENNESSEE                     91.0
# 1  47169       10231  Urban  Trousdale  TENNESSEE                      2.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
#
#    unemployment_rate  pcp_per_100k
# 0                4.3     49.608312
# 1                4.7     19.548431

# %%
physicians['county'] = physicians['county'].str.upper()

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     SUMNER  TENNESSEE                     91.0
# 1  47169       10231  Urban  TROUSDALE  TENNESSEE                      2.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
#
#    unemployment_rate  pcp_per_100k
# 0                4.3     49.608312
# 1                4.7     19.548431

# %%
hospitals.head(2)
# Out:
#      COUNTY  Hospital_Count
# 0    SHELBY              23
# 1  DAVIDSON              15

# %%
physicians = pd.merge(left = physicians,
         right = hospitals.rename(columns = {'COUNTY': 'county'}),
         on='county',
        how='left'
        )

# %%
physicians.head(2)
# Out:
#     FIPS  population  urban     county      state  primary_care_physicians  \
# 0  47165      183437  Urban     SUMNER  TENNESSEE                     91.0
# 1  47169       10231  Urban  TROUSDALE  TENNESSEE                      2.0
#
#    residents_per_pcp        shadac_category      LF  Employed  Unemployed  \
# 0        2015.791209  moderately inadequate  103331     98879        4452
# 1        5115.500000         low inadequate    5473      5217         256
#
#    unemployment_rate  pcp_per_100k  Hospital_Count
# 0                4.3     49.608312             3.0
# 1                4.7     19.548431             1.0

# %%
help_counties['urban'].value_counts()
# Out:
# Rural    18
# Urban     8
# Name: urban, dtype: int64

# %% [markdown]
# Most counties in this help group are rural. Which comparisons do I want to make?
# unemployment rate would be a demographic to look at, but how?

# %% [markdown]
# Second, TN Med Helper is interested in reducing the number of potentially preventable hospitalizations. Do areas that lack access to healthcare tend to have higher rates of emergency department visits or hospitalizations? Is there an association between the percentage of beneficiaries who had an annual wellness visit and rate of hospitalizations or emergency department visits?

# %%
closures = pd.read_excel('../data/Closures-Database-for-Web.xlsx',
              sheet_name = 'Sheet1',
             header = 0,
             usecols = 'B, C, D, E, F, G, H, I, J, K, L')
closures.head(2)
# Out:
#                                  Hospital                 Address       City  \
# 0         MercyOne Oakland Medical Center  601 East Second Street    Oakland
# 1  Community HealthCare System- St. Marys           206 Grand Ave  St. Marys
#
#   State    Zip  RUCA     CBSA Medicare Payment  # of Beds Closure Month  \
# 0    NE  68045  10.0  Neither              CAH         16          July
# 1    KS  66536   7.0    Metro              CAH         25          June
#
#    Closure Year
# 0          2021
# 1          2021

# %%
closures.loc[(closures['State'] == 'TN')]
# Out:
#                                     Hospital                     Address  \
# 2                     Jellico Medical Center           188 HOSPITAL LANE
# 3                   Perry Community Hospital  2718 Squirrel Hollow Drive
# 7                  Cumberland River Hospital        100 OLD JEFFERSON ST
# 13           Decatur County General Hospital         969 Tennessee Ave S
# 30         Jamestown Regional Medical Center     436 CENTRAL AVENUE WEST
# 33                  Takoma Regional Hospital     1420 TUSCULUM BOULEVARD
# 49                McKenzie Regional Hospital          161 HOSPITAL DRIVE
# 57               Copper Basin Medical Center                  HIGHWAY 68
# 72     Tennova Healthcare - McNairy Regional            705 E POPLAR AVE
# 89            United Regional Medical Center        481 INTERSTATE DRIVE
# 90                   Parkridge West Hospital             1000 HIGHWAY 28
# 100                  Gibson General Hospital             200 HOSPITAL DR
# 101                    Humboldt General Hosp         3525 CHERE CAROL RD
# 102          Haywood Park Community Hospital       2545 N WASHINGTON AVE
# 117               Starr Regional Medical Ctr       886 HIGHWAY 411 NORTH
# 122  Riverview Regional Medical Center South         130 LEBANON HIGHWAY
#
#             City State    Zip  RUCA     CBSA Medicare Payment  # of Beds  \
# 2        JELLICO    TN  37762  10.0    Metro              PPS         54
# 3         Linden    TN  37096  10.0  Neither              PPS         25
# 7         Celina    TN  38551   6.0  Neither              PPS          1
# 13       Parsons    TN  38363  10.0  Neither              MDH         40
# 30     Jamestown    TN  38556  10.2  Neither              SCH         54
# 33   Greeneville    TN  37745   4.0    Micro              MDH         73
# 49      McKenzie    TN  38201   7.0  Neither              PPS         29
# 57    Copperhill    TN  37317  10.1    Metro              CAH         21
# 72        Selmer    TN  38375   7.0  Neither              MDH         26
# 89    Manchester    TN  37355   4.0    Micro              PPS         53
# 90        Jasper    TN  37347   7.1    Metro              PPS         50
# 100      Trenton    TN  38382   7.0  Neither              MDH         41
# 101     Humboldt    TN  38343   7.1  Neither              PPS         42
# 102  Brownsville    TN  38012   7.1  Neither              MDH         36
# 117       Etowah    TN  37331   7.2    Micro              MDH         60
# 122     Carthage    TN  37030   5.0    Metro              CAH         25
#
#     Closure Month  Closure Year
# 2        November          2020
# 3        November          2020
# 7          August          2020
# 13          April          2020
# 30           June          2019
# 33          April          2019
# 49      September          2018
# 57            May          2017
# 72            May          2016
# 89           July          2015
# 90          April          2015
# 100       January          2014
# 101       January          2014
# 102          July          2014
# 117      December          2013
# 122        August          2012

# %%
tn_closures = closures.loc[(closures['State'] == 'TN')]
tn_closures.shape
# Out:
# (16, 11)

# %% [markdown]
# tn_closures sorts hospital closures in TN from 2019-2020

# %%
annual_wellness = pd.read_csv('../data/Medicare_Disparities_by_Population/annual_wellness.csv')
annual_wellness.head(2)
# Out:
#    year geography              measure         adjustment      analysis  \
# 0  2019    County  Preventive Services  Unsmoothed actual  Base measure
# 1  2019    County  Preventive Services  Unsmoothed actual  Base measure
#
#                 domain              condition primary_sex primary_age  \
# 0  Preventive Services  Annual Wellness Visit         All         All
# 1  Preventive Services  Annual Wellness Visit         All         All
#
#       primary_dual  fips          county    state  urban primary_race  \
# 0  Dual & non-dual  1001  Autauga County  ALABAMA  Urban          All
# 1  Dual & non-dual  1003  Baldwin County  ALABAMA  Rural          All
#
#   primary_eligibility primary_denominator  analysis_value
# 0                 All         1,000-4,999              29
# 1                 All             10,000+              29

# %%
annual_wellness = annual_wellness[['fips', 'county', 'state', 'urban', 'primary_race', 'primary_eligibility', 'primary_denominator', 'analysis_value']]

# %%
tn_annual_wellness = annual_wellness.loc[(annual_wellness['state'] == 'TENNESSEE')]
tn_annual_wellness.head(2)
# Out:
#        fips           county      state  urban primary_race  \
# 2428  47001  Anderson County  TENNESSEE  Urban          All
# 2429  47003   Bedford County  TENNESSEE  Rural          All
#
#      primary_eligibility primary_denominator  analysis_value
# 2428                 All         5,000-9,999              35
# 2429                 All         1,000-4,999              46
